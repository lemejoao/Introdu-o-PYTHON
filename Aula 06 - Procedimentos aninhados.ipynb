# %% [markdown]
# ![imagem%20unesp%20rosana.jpg](attachment:imagem%20unesp%20rosana.jpg)
# # Oficina Analytics

# %% [markdown]
# ## Procedimentos Aninhados

# %% [markdown]
# criar tres vetores
# v1=list()
# v2=list()
# v3
#
# def i que pega o maior valor e divido pelor menor
# i(v1)
# i

# %%
lista =[5,2,9,2]
min?

# %%
def pessoa(a):
    return a + " vai a/ao"

# %%
def lugar(b):
    return b + "!!!"

# %%
sujeito
def frase(s):
    sujeito = str(input(a)
    local = lugar(b)
    return sujeito + " " + local

# %%
frase('João','Angra')
# Out:
# 'João vai a/ao Angra!!!'

# %% [markdown]
# Podemos aninhar procedimentos e essa é uma as funções do retorno, ou seja, passar um parâmetro para outro procedimento e obter assim um resultado mais complexo

# %%
#Dados 3 números, descubra o maior deles.
#Há varias formas de resolver o problema

# %%
def maiorNum(a,b):
    if a > b:
        return a
    elif b > a:
        return b
    else:
        return a

# %%
maiorNum(21,20)
# Out:
# 21

# %%
def maiorTres(a,b,c):
    aux = maiorNum(a,b)
    if aux > c:
        return aux
    elif c > aux:
        return c
    else:
        return aux

# %%
maiorTres(56,653,862)
# Out:
# 862
